# %% [markdown]
# # Lots - Version 1

# %%
import pandas as pd
import plotly.express as px
import aesoppy.aesop as aesop
import os

# Comon Variables
data = os.path.join(os.getcwd(), 'data')

# DataFrames
lots_df = pd.read_csv(os.path.join(data, 'lots.csv'))
lots_df['date'] = pd.to_datetime(lots_df['date'], format='%m/%d/%y')
lots_df.set_index('date', inplace=True)

# Current Data
stock_price = 184.61
fwd_div = 5.44
current_year = aesop.aesop_now.year
# Out:
# /Users/harveywargo/Desktop/GithubProjects/Freedom-Fund-Repo/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
lots_df['fwd_div'] = fwd_div
lots_df['lot_year'] = lots_df.index.year
lots_df['price'] = stock_price
lots_df['current_year'] = aesop.aesop_now.year
lots_df['yoc'] = round((lots_df['fwd_div'] / lots_df['lot_cost']) * 100, 2)
lots_df['end_total'] = lots_df['price'] + lots_df['div_total']
lots_df['end_begin'] = lots_df['end_total'] / lots_df['lot_cost']
lots_df['period'] = 1 / (lots_df['current_year'] - lots_df['lot_year'])
lots_df['cagr'] = round(((lots_df['end_begin'] ** lots_df['period']) - 1) * 100, 2)
lots_df
# Out:
#             lot_cost  lot_div  div_total  fwd_div  lot_year   price  \
# date
# 2023-11-13    145.84     5.20       7.92     5.44      2023  184.61
# 2023-11-08    145.27     5.20       7.92     5.44      2023  184.61
# 2023-02-23    169.43     4.96      10.40     5.44      2023  184.61
# 2022-10-10    156.78     4.60      12.88     5.44      2022  184.61
# 2022-07-11    153.36     4.60      14.03     5.44      2022  184.61
# 2022-07-05    145.69     4.60      14.03     5.44      2022  184.61
# 2020-03-10    105.97     3.60      23.26     5.44      2020  184.61
# 2018-11-12     93.85     3.08      28.24     5.44      2018  184.61
# 2018-10-30     91.97     3.08      28.24     5.44      2018  184.61
# 2018-10-29     91.82     2.48      28.24     5.44      2018  184.61
#
#             current_year   yoc  end_total  end_begin    period   cagr
# date
# 2023-11-13          2025  3.73     192.53   1.320145  0.500000  14.90
# 2023-11-08          2025  3.74     192.53   1.325325  0.500000  15.12
# 2023-02-23          2025  3.21     195.01   1.150977  0.500000   7.28
# 2022-10-10          2025  3.47     197.49   1.259663  0.333333   8.00
# 2022-07-11          2025  3.55     198.64   1.295253  0.333333   9.01
# 2022-07-05          2025  3.73     198.64   1.363443  0.333333  10.89
# 2020-03-10          2025  5.13     207.87   1.961593  0.200000  14.43
# 2018-11-12          2025  5.80     212.85   2.267981  0.142857  12.41
# 2018-10-30          2025  5.91     212.85   2.314342  0.142857  12.74
# 2018-10-29          2025  5.92     212.85   2.318122  0.142857  12.76
